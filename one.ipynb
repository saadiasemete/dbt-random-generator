# %%
import sqlglot

# %%
import faker

# %%
import faker.providers


faker.providers
# Out:
# <module 'faker.providers' from 'c:\\Users\\Mike\\Documents\\grimoires\\learning\\dbt-random-generator\\.venv\\Lib\\site-packages\\faker\\providers\\__init__.py'>

# %%
import faker.generator


faker.generator
# Out:
# <module 'faker.generator' from 'c:\\Users\\Mike\\Documents\\grimoires\\learning\\dbt-random-generator\\.venv\\Lib\\site-packages\\faker\\generator.py'>

# %%
from faker import Faker

fake = Faker()
[ i for i in dir(fake) if not i.startswith('_') and not i.endswith('__')]
# Out:
# ['aba',
#  'add_provider',
#  'address',
#  'administrative_unit',
#  'am_pm',
#  'android_platform_token',
#  'ascii_company_email',
#  'ascii_email',
#  'ascii_free_email',
#  'ascii_safe_email',
#  'bank_country',
#  'basic_phone_number',
#  'bban',
#  'binary',
#  'boolean',
#  'bothify',
#  'bs',
#  'building_number',
#  'cache_pattern',
#  'catch_phrase',
#  'century',
#  'chrome',
#  'city',
#  'city_prefix',
#  'city_suffix',
#  'color',
#  'color_hsl',
#  'color_hsv',
#  'color_name',
#  'color_rgb',
#  'color_rgb_float',
#  'company',
#  'company_email',
#  'company_suffix',
#  'coordinate',
#  'country',
#  'country_calling_code',
#  'country_code',
#  'credit_card_expire',
#  'credit_card_full',
#  'credit_card_number',
#  'credit_card_provider',
#  'credit_card_security_code',
#  'cryptocurrency',
#  'cryptocurrency_code',
#  'cryptocurrency_name',
#  'csv',
#  'currency',
#  'currency_code',
#  'currency_name',
#  'currency_symbol',
#  'current_country',
# ...
